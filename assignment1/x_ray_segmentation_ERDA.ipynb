# %% [markdown]
# # U-Net segmentation example
# ### Advanced Deep Learning 2022
# This notebook was originally written by Mathias Perslev. It has been changed slightly by Christian Igel and subsequently slightly updated [Stefan Sommer](mailto:sommer@di.ku.dk).
#
# The U-Net is based on code written by Annika Brundyn and Akshay Kulkarni distributed as part of [*PyTorch Lightning Bolts*](https://pytorch-lightning.readthedocs.io/) under the  [Apache 2.0 license](https://www.apache.org/licenses/LICENSE-2.0.txt).
#
# We consider the data described in:
#
# Bram van Ginneken, Mikkel B. Stegmann, Marco Loog. [Segmentation of anatomical structures in chest radiographs using supervised methods: a comparative study on a public database](https://doi.org/10.1016/j.media.2005.02.002). *Medical Image Analysis* 10(1): 19-40, 2006

# %% [markdown]
# ## Installs
#
# If some packages are missing:

# %%
pip install -q pytorch_lightning lightning-bolts

# %% [markdown]
# ## Imports

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

import torch
from torch import nn as nn
from torch.nn import functional as F
from torchvision.datasets.utils import download_url

import torchmetrics

from pprint import pformat
from skimage.transform import resize
#from sklearn.metrics import f1_score
from pathlib import Path
from glob import glob
from matplotlib.pyplot import imread
from collections import defaultdict

# %% [markdown]
# ## Mount Google drive when using Google Colab

# %%
try:
    from google.colab import drive
    drive.mount('/content/gdrive/')
    os.chdir('gdrive/MyDrive/ADL2022')
except:
    print('Google drive not mounted')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# Google drive not mounted

# %% [markdown]
# ## Test for GPU support

# %%
# GPU support?
gpu = torch.cuda.is_available()
device = torch.device("cuda:0" if gpu else "cpu")
print("device:", device)
# Out:
# device: cuda:0

# %% [markdown]
# ## U-Net
# Import the U-Net.

# %%
# from pl_bolts.models.vision import UNet
class UNet(nn.Module):
    def __init__(
        self,
        num_classes: int,
        input_channels: int = 3,
        num_layers: int = 5,
        features_start: int = 64,
        mode: str = 'bilinear',
    ):

        if num_layers < 1:
            raise ValueError(f"num_layers = {num_layers}, expected: num_layers > 0")

        super().__init__()
        self.num_layers = num_layers

        layers = [DoubleConv(input_channels, features_start)]

        feats = features_start
        for _ in range(num_layers - 1):
            layers.append(Down(feats, feats * 2))
            feats *= 2

        for _ in range(num_layers - 1):
            layers.append(Up(feats, feats // 2, 'nearest'))
            feats //= 2

        layers.append(nn.Conv2d(feats, num_classes, kernel_size=1))

        self.layers = nn.ModuleList(layers)

    def forward(self, x):
        xi = [self.layers[0](x)]
        # Down path
        for layer in self.layers[1 : self.num_layers]:
            xi.append(layer(xi[-1]))
        # Up path
        for i, layer in enumerate(self.layers[self.num_layers : -1]):
            xi[-1] = layer(xi[-1], xi[-2 - i])
        return self.layers[-1](xi[-1])


class DoubleConv(nn.Module):
    def __init__(self, in_ch: int, out_ch: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            # nn.ReLU(inplace=True),
            nn.ELU(inplace=True),
            nn.Conv2d(out_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            # nn.ReLU(inplace=True),
            nn.ELU(inplace=True),
        )

    def forward(self, x):
        return self.net(x)


class Down(nn.Module):
    """Downscale with MaxPool => DoubleConvolution block."""

    def __init__(self, in_ch: int, out_ch: int):
        super().__init__()
        self.net = nn.Sequential(nn.MaxPool2d(kernel_size=2, stride=2), DoubleConv(in_ch, out_ch))

    def forward(self, x):
        return self.net(x)


class Up(nn.Module):
    """Upsampling (by either bilinear interpolation or transpose convolutions) followed by concatenation of feature
    map from contracting path, followed by DoubleConv."""

    def __init__(self, in_ch: int, out_ch: int, mode: str = 'bilinear'):
        super().__init__()
        self.upsample = None
        if mode == 'bilinear':
            self.upsample = nn.Sequential(
                nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True),
                nn.Conv2d(in_ch, in_ch // 2, kernel_size=1),
            )
        elif mode == 'nearest':
            self.upsample = nn.Sequential(
                nn.Upsample(scale_factor=2, mode="nearest"),
                nn.Conv2d(in_ch, in_ch // 2, kernel_size=1),
            )
        else:
            self.upsample = nn.ConvTranspose2d(in_ch, in_ch // 2, kernel_size=2, stride=2)
    
        self.conv = DoubleConv(in_ch, out_ch)

    def forward(self, x1, x2):
        x1 = self.upsample(x1)

        # Pad x1 to the size of x2
        diff_h = x2.shape[2] - x1.shape[2]
        diff_w = x2.shape[3] - x1.shape[3]

        x1 = F.pad(x1, [diff_w // 2, diff_w - diff_w // 2, diff_h // 2, diff_h - diff_h // 2])

        # Concatenate along the channels axis
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)

# %% [markdown]
# ## Database

# %% [markdown]
# Load database with chest X-rays with lung segmentations.

# %%
data_root='./datasets'
data_npz='lung_field_dataset.npz'
data_fn = os.path.join(data_root, "lung_field_dataset.npz")
force_download = False

if (not os.path.exists(data_fn)) or force_download:
  download_url("https://sid.erda.dk/share_redirect/gCTc6o3KAh", data_root, data_npz)
else:
  print('Using existing', data_fn)
# Out:
# Using existing ./datasets/lung_field_dataset.npz

# %%
def plot_image_with_segmentation(image, segmentation, ax=None):
    """
    Plots an image with overlayed segmentation mask
    
    Returns: plt.fig and ax objects
    """
    if ax is None:
        fig = plt.figure(figsize=(8, 8))
        ax = fig.add_subplot(111)
        ax.axis("off")
    
    ax.imshow(image.squeeze(), cmap="gray")
    mask = np.ma.masked_where(segmentation == 0, segmentation)
    ax.imshow(mask.squeeze(), cmap="Set1", alpha=0.5)
    return plt.gcf(), ax


def load_npz_dataset(path, keys=('x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test')):
    archive = np.load(path)
    return [archive.get(key) for key in keys]

# %%
# Load train/val/test data
x_train, y_train, x_val, y_val, x_test, y_test = load_npz_dataset(data_fn)
# Bring images into PyTorch format
x_train = np.moveaxis(x_train, 3, 1)
y_train = np.moveaxis(y_train, 3, 1)
x_val = np.moveaxis(x_val, 3, 1)
y_val = np.moveaxis(y_val, 3, 1)
x_test = np.moveaxis(x_test, 3, 1)
y_test = np.moveaxis(y_test, 3, 1)

print("x train:", x_train.shape)
print("y train:", y_train.shape)
print("x val: ", x_val.shape)
print("y val: ", y_val.shape)
print("x test:", x_test.shape)
print("y test:", y_test.shape)

# Plot an example
fig, ax = plot_image_with_segmentation(x_train[0], y_train[0])
plt.show()
# Out:
# x train: (112, 1, 256, 256)
# y train: (112, 1, 256, 256)
# x val:  (12, 1, 256, 256)
# y val:  (12, 1, 256, 256)
# x test: (123, 1, 256, 256)
# y test: (123, 1, 256, 256)

# %% [markdown]
# ### Init torch dataloaders

# %%
def as_torch_dataset(x_arr, y_arr):
    """
    Takes two numpy arrays of data points and labels (x_arr and y_arr, respectively) and
    returns a torch TensorDataset object.
    
    Returns: torch.utils.data.TensorDataset
    """
    dataset = torch.utils.data.TensorDataset(
        torch.FloatTensor(x_arr), 
        torch.LongTensor(y_arr)
    )
    return dataset

# Init torch datasets
train_dataset = as_torch_dataset(x_train, y_train.squeeze(1))  # remove dummy channel dim
val_dataset = as_torch_dataset(x_val, y_val.squeeze(1))
test_dataset = as_torch_dataset(x_test, y_test.squeeze(1))

# Init dataloaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=False)

# %% [markdown]
# ### Function for evaluating a model on a data loader

# %%
def evaluate_model(model, data_loader, metrics_dict, reduction=True, device=device):
    """
    Evaluate a model 'model' on all batches of a torch DataLoader 'data_loader'.
    On each batch, compute all metric functions stored in dictionary 'metrics_dict'.
    
    Returns: dict of metric_name: (list of batch-wise metrics if reduction == False, else single scalar)
    """
    
    # defaultdict(list) returns a dictionary-like object with default_factory list. 
    # When a new key is encountered, an entry is automatically created of type default_factory. 
    metrics = defaultdict(list)
    with torch.no_grad():
        for batch_x, batch_y in data_loader:
            # Predict on batch
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            logits = model(batch_x)
            
            # Compute all metrics
            for metric_name, metric_func in metrics_dict.items():
                value = metric_func(logits.cpu(), batch_y.cpu()).item() #.cpu().numpy()
                metrics[metric_name].append(value)
    
    if reduction == True:
        # Return mean values
        return {key: np.mean(value) for key, value in metrics.items()}
    else:
        return metrics

# %% [markdown]
# ## Main trainig loop function(s)
#
# We want to track the F1 score during training. This generates some additional code.

# %%
def run_one_epoch(model, loss, optimizer, train_loader, val_loader, n_epochs, metrics_dict, device=device):
    """
    Run 1 epoch of training
    Changes to model parameters and optimizer occour internally (state updates)
    Returns:
        two dictionaries, training and a validation metrics
    """
    train_losses = []
    for i, (batch_x, batch_y) in enumerate(train_loader):
        # Zero out stored gradients for all parameters
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        
        print(f"   -- Batch {i+1}/{len(train_loader)}", end=" / ")
        # Predict on batch
        logits = model(batch_x)
        
        # Compute loss function
        loss_tensor = loss(logits, batch_y)
        loss_scalar = loss_tensor.detach().cpu().numpy()
        train_losses.append(loss_scalar)
        print("Loss: ", loss_scalar)
        
        # Backprop and step
        loss_tensor.backward()
        optimizer.step()
        
    # Run validation
    print("   Validation running...")
    val_metrics = evaluate_model(
        model=model, 
        data_loader=val_loader,
        metrics_dict=metrics_dict
    )
    # Return loss and metrics as dicts
    return {"loss": np.mean(train_losses)}, val_metrics


def merge_list_of_dicts(list_of_dicts):
    """
    Takes a list of dictionaries and merges them into a single dictionary pointing to lists
    
    E.g. [{"loss": 5}, {"loss": 3}, {"loss": -2, "F1": 0.5}] --> {"loss": [5, 3, -2], "F1": [0.5]}
    
    Returns: dict
    """
    merged = defaultdict(list)
    for dict_ in list_of_dicts:
        for value, key in dict_.items():
            merged[value].append(key)
    return merged


def training_loop(model, loss, optimizer, train_loader, val_loader, n_epochs, init_epoch=None, metrics_dict=None, save_path=None):
    """
    Run training of a model given a loss function, optimizer and a set of training and validation data.
    Supports computing additional metrics on the validation set (only) via the metrics_dict param.
    Specify save_path to store the model at each epoch.
    
    Returns: 
        Two lists of metric dictionaries for each epoch for training and validation, specifically
    """
    train_history, val_history = [], []
    
    metrics_with_loss = {"loss": loss}
    if metrics_dict is not None:
        metrics_with_loss.update(metrics_dict)
    
    if init_epoch == None:
        init_epoch = 0
    try:
        for i in range(init_epoch, n_epochs):
            print(f"Epoch {i+1}/{n_epochs}")
            train_metrics, val_metrics = run_one_epoch(
                model=model, 
                loss=loss, 
                optimizer=optimizer, 
                train_loader=train_loader, 
                val_loader=val_loader, 
                n_epochs=n_epochs,
                metrics_dict=metrics_with_loss
            )
            print("   Mean epoch metrics:")
            print(f"   Training:   {pformat(train_metrics)}")
            print(f"   Validation: {pformat(val_metrics)}")
            train_history.append(train_metrics), val_history.append(val_metrics)
            
            if save_path:
                save_path_epoch = f"epoch_{i+1}_{save_path}"
                print(f"   Saving to: {save_path_epoch}")
                save_model(model, save_path_epoch, optimizer)
    except KeyboardInterrupt:
        print("Training stopped.")
        pass
    
    # Merge list of training and validation dicts into single dicts    
    return merge_list_of_dicts(train_history), merge_list_of_dicts(val_history)

# %% [markdown]
# ## Function for plotting training/validation histories

# %%
def plot_histories(train_history=None, val_history=None, label="Loss"):
    """
    Takes a list of training and/or validation metrics and plots them
    Returns: plt.figure and ax objects
    """
    if not train_history and not val_history:
        raise ValueError("Must specify at least one of 'train_histories' and 'val_histories'")
    fig = plt.figure(figsize=(5, 3))
    ax = fig.add_subplot(111)
    
    epochs = np.arange(len(train_history or val_history))
    if train_history:
        ax.plot(epochs, train_history, label="Training", color="black")
    if val_history:
        ax.plot(epochs, val_history, label="Validation", color="darkred")
    
    ax.set_xlabel("Epoch")
    ax.set_ylabel(label)
    ax.legend(loc=0)
    
    return fig, ax

# %% [markdown]
# ## Functions for saving and loading model and optimizer state

# %%
def save_model(model, path, optimizer=None):
    """
    Saves the state_dict of a torch model and optional optimizer to 'path'
    Returns: None
    """
    state = {"model": model.state_dict()}
    if optimizer is not None:
        state["optimizer"] = optimizer.state_dict()
    torch.save(state, path)


def load_model(model, path, optimizer=None):
    """
    Loads the state_dict of a torch model and optional optimizer from 'path'
    Returns: None
    """
    state = torch.load(path)
    model.load_state_dict(state["model"])
    if optimizer is not None:
        optimizer.load_state_dict(state["optimizer"])

# %% [markdown]
# ## Init U-Net model and optimizer

# %%
# Init U-Net model
model = UNet(
    num_classes=2, 
    input_channels=1, 
    num_layers=4, 
    features_start=16,
)

model.to(device)

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %% [markdown]
# ## Continue training?

# %%
# Specify integer, starting at 1
init_epoch = None
if init_epoch != None:
    load_model(model, f"epoch_{init_epoch}_model.ckpt", optimizer)

# %% [markdown]
# ## Run training

# %%
# Define loss and metrics
loss = torch.nn.CrossEntropyLoss(reduction="mean")
metrics = {"f1": torchmetrics.classification.F1Score(num_classes=2, average="macro", mdmc_average="samplewise")}

# Run training
train_history, val_history = training_loop(
    model=model,
    loss=loss, 
    optimizer=optimizer, 
    train_loader=train_loader, 
    val_loader=val_loader,
    init_epoch=init_epoch,
    n_epochs=100,
    metrics_dict=metrics,
    save_path="model.ckpt"
)
# Out:
# Epoch 1/100
#    -- Batch 1/7 / Loss:  0.6849626
#    -- Batch 2/7 / Loss:  0.560075
#    -- Batch 3/7 / Loss:  0.500789
#    -- Batch 4/7 / Loss:  0.49041757
#    -- Batch 5/7 / Loss:  0.46914357
#    -- Batch 6/7 / Loss:  0.44953474
#    -- Batch 7/7 / Loss:  0.42346022
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.5111975}
#    Validation: {'f1': 0.8254572153091431, 'loss': 0.40807223320007324}
#    Saving to: epoch_1_model.ckpt
# Epoch 2/100
#    -- Batch 1/7 / Loss:  0.40784636
#    -- Batch 2/7 / Loss:  0.41589156
#    -- Batch 3/7 / Loss:  0.40301627
#    -- Batch 4/7 / Loss:  0.37727767
#    -- Batch 5/7 / Loss:  0.36053133
#    -- Batch 6/7 / Loss:  0.33869624
#    -- Batch 7/7 / Loss:  0.3424999
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.37796563}
#    Validation: {'f1': 0.9014841318130493, 'loss': 0.3277323544025421}
#    Saving to: epoch_2_model.ckpt
# Epoch 3/100
#    -- Batch 1/7 / Loss:  0.3139484
#    -- Batch 2/7 / Loss:  0.34445852
#    -- Batch 3/7 / Loss:  0.32058954
#    -- Batch 4/7 / Loss:  0.3069046
#    -- Batch 5/7 / Loss:  0.31067187
#    -- Batch 6/7 / Loss:  0.31248754
#    -- Batch 7/7 / Loss:  0.29181126
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.31441024}
#    Validation: {'f1': 0.9228132963180542, 'loss': 0.28218743205070496}
#    Saving to: epoch_3_model.ckpt
# Epoch 4/100
#    -- Batch 1/7 / Loss:  0.29854882
#    -- Batch 2/7 / Loss:  0.28935748
#    -- Batch 3/7 / Loss:  0.27174738
#    -- Batch 4/7 / Loss:  0.26558322
#    -- Batch 5/7 / Loss:  0.27382874
#    -- Batch 6/7 / Loss:  0.25892735
#    -- Batch 7/7 / Loss:  0.26027986
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.274039}
#    Validation: {'f1': 0.9355032444000244, 'loss': 0.2507418096065521}
#    Saving to: epoch_4_model.ckpt
# Epoch 5/100
#    -- Batch 1/7 / Loss:  0.24621189
#    -- Batch 2/7 / Loss:  0.24794596
#    -- Batch 3/7 / Loss:  0.24563332
#    -- Batch 4/7 / Loss:  0.24575828
#    -- Batch 5/7 / Loss:  0.23229894
#    -- Batch 6/7 / Loss:  0.25218213
#    -- Batch 7/7 / Loss:  0.22348626
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.24193098}
#    Validation: {'f1': 0.9468584656715393, 'loss': 0.2282215803861618}
#    Saving to: epoch_5_model.ckpt
# Epoch 6/100
#    -- Batch 1/7 / Loss:  0.23627922
#    -- Batch 2/7 / Loss:  0.22503628
#    -- Batch 3/7 / Loss:  0.22519633
#    -- Batch 4/7 / Loss:  0.21854217
#    -- Batch 5/7 / Loss:  0.21926323
#    -- Batch 6/7 / Loss:  0.2092722
#    -- Batch 7/7 / Loss:  0.20280673
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.21948518}
#    Validation: {'f1': 0.9523742198944092, 'loss': 0.20872372388839722}
#    Saving to: epoch_6_model.ckpt
# Epoch 7/100
#    -- Batch 1/7 / Loss:  0.21717997
#    -- Batch 2/7 / Loss:  0.21227284
#    -- Batch 3/7 / Loss:  0.20349471
#    -- Batch 4/7 / Loss:  0.20631747
#    -- Batch 5/7 / Loss:  0.21052447
#    -- Batch 6/7 / Loss:  0.1884157
#    -- Batch 7/7 / Loss:  0.18615851
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20348053}
#    Validation: {'f1': 0.9560916423797607, 'loss': 0.19333088397979736}
#    Saving to: epoch_7_model.ckpt
# Epoch 8/100
#    -- Batch 1/7 / Loss:  0.20686819
#    -- Batch 2/7 / Loss:  0.20942104
#    -- Batch 3/7 / Loss:  0.1739078
#    -- Batch 4/7 / Loss:  0.19668204
#    -- Batch 5/7 / Loss:  0.1825063
#    -- Batch 6/7 / Loss:  0.18876521
#    -- Batch 7/7 / Loss:  0.17329815
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19020696}
#    Validation: {'f1': 0.9586849212646484, 'loss': 0.1831565946340561}
#    Saving to: epoch_8_model.ckpt
# Epoch 9/100
#    -- Batch 1/7 / Loss:  0.17064075
#    -- Batch 2/7 / Loss:  0.18988708
#    -- Batch 3/7 / Loss:  0.1768161
#    -- Batch 4/7 / Loss:  0.17945509
#    -- Batch 5/7 / Loss:  0.17787282
#    -- Batch 6/7 / Loss:  0.17617221
#    -- Batch 7/7 / Loss:  0.18239488
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17903413}
#    Validation: {'f1': 0.9607212543487549, 'loss': 0.17654182016849518}
#    Saving to: epoch_9_model.ckpt
# Epoch 10/100
#    -- Batch 1/7 / Loss:  0.17576538
#    -- Batch 2/7 / Loss:  0.16346401
#    -- Batch 3/7 / Loss:  0.1736496
#    -- Batch 4/7 / Loss:  0.17333227
#    -- Batch 5/7 / Loss:  0.17100875
#    -- Batch 6/7 / Loss:  0.16742344
#    -- Batch 7/7 / Loss:  0.16270585
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16962135}
#    Validation: {'f1': 0.9628735780715942, 'loss': 0.16953104734420776}
#    Saving to: epoch_10_model.ckpt
# Epoch 11/100
#    -- Batch 1/7 / Loss:  0.16559942
#    -- Batch 2/7 / Loss:  0.16491415
#    -- Batch 3/7 / Loss:  0.16237801
#    -- Batch 4/7 / Loss:  0.17271207
#    -- Batch 5/7 / Loss:  0.1520569
#    -- Batch 6/7 / Loss:  0.16464737
#    -- Batch 7/7 / Loss:  0.16275612
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16358057}
#    Validation: {'f1': 0.9654930830001831, 'loss': 0.16128645837306976}
#    Saving to: epoch_11_model.ckpt
# Epoch 12/100
#    -- Batch 1/7 / Loss:  0.17184345
#    -- Batch 2/7 / Loss:  0.15741952
#    -- Batch 3/7 / Loss:  0.16147767
#    -- Batch 4/7 / Loss:  0.1643016
#    -- Batch 5/7 / Loss:  0.14234892
#    -- Batch 6/7 / Loss:  0.14728495
#    -- Batch 7/7 / Loss:  0.15198824
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15666635}
#    Validation: {'f1': 0.9670773148536682, 'loss': 0.15512612462043762}
#    Saving to: epoch_12_model.ckpt
# Epoch 13/100
#    -- Batch 1/7 / Loss:  0.15411478
#    -- Batch 2/7 / Loss:  0.15861769
#    -- Batch 3/7 / Loss:  0.15519604
#    -- Batch 4/7 / Loss:  0.1566625
#    -- Batch 5/7 / Loss:  0.14601716
#    -- Batch 6/7 / Loss:  0.14176565
#    -- Batch 7/7 / Loss:  0.14934874
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15167464}
#    Validation: {'f1': 0.9681044816970825, 'loss': 0.1503608524799347}
#    Saving to: epoch_13_model.ckpt
# Epoch 14/100
#    -- Batch 1/7 / Loss:  0.16003877
#    -- Batch 2/7 / Loss:  0.14410636
#    -- Batch 3/7 / Loss:  0.14759189
#    -- Batch 4/7 / Loss:  0.15301321
#    -- Batch 5/7 / Loss:  0.14796671
#    -- Batch 6/7 / Loss:  0.14528008
#    -- Batch 7/7 / Loss:  0.13400333
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14742862}
#    Validation: {'f1': 0.967164158821106, 'loss': 0.14922353625297546}
#    Saving to: epoch_14_model.ckpt
# Epoch 15/100
#    -- Batch 1/7 / Loss:  0.14462213
#    -- Batch 2/7 / Loss:  0.14723678
#    -- Batch 3/7 / Loss:  0.15578164
#    -- Batch 4/7 / Loss:  0.13489273
#    -- Batch 5/7 / Loss:  0.1408561
#    -- Batch 6/7 / Loss:  0.14281581
#    -- Batch 7/7 / Loss:  0.14379664
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14428596}
#    Validation: {'f1': 0.9693853855133057, 'loss': 0.14486636221408844}
#    Saving to: epoch_15_model.ckpt
# Epoch 16/100
#    -- Batch 1/7 / Loss:  0.15514179
#    -- Batch 2/7 / Loss:  0.14259581
#    -- Batch 3/7 / Loss:  0.14440215
#    -- Batch 4/7 / Loss:  0.13414387
#    -- Batch 5/7 / Loss:  0.13961871
#    -- Batch 6/7 / Loss:  0.13023725
#    -- Batch 7/7 / Loss:  0.12998942
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13944699}
#    Validation: {'f1': 0.9702382683753967, 'loss': 0.13964428007602692}
#    Saving to: epoch_16_model.ckpt
# Epoch 17/100
#    -- Batch 1/7 / Loss:  0.1411745
#    -- Batch 2/7 / Loss:  0.12653512
#    -- Batch 3/7 / Loss:  0.14414501
#    -- Batch 4/7 / Loss:  0.12579334
#    -- Batch 5/7 / Loss:  0.1425803
#    -- Batch 6/7 / Loss:  0.14089216
#    -- Batch 7/7 / Loss:  0.13321438
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13633354}
#    Validation: {'f1': 0.9712846279144287, 'loss': 0.13761937618255615}
#    Saving to: epoch_17_model.ckpt
# Epoch 18/100
#    -- Batch 1/7 / Loss:  0.12601924
#    -- Batch 2/7 / Loss:  0.13258034
#    -- Batch 3/7 / Loss:  0.1256278
#    -- Batch 4/7 / Loss:  0.15508041
#    -- Batch 5/7 / Loss:  0.12711136
#    -- Batch 6/7 / Loss:  0.13262437
#    -- Batch 7/7 / Loss:  0.14053895
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13422607}
#    Validation: {'f1': 0.9723710417747498, 'loss': 0.13435260951519012}
#    Saving to: epoch_18_model.ckpt
# Epoch 19/100
#    -- Batch 1/7 / Loss:  0.137987
#    -- Batch 2/7 / Loss:  0.12482114
#    -- Batch 3/7 / Loss:  0.14500935
#    -- Batch 4/7 / Loss:  0.12589428
#    -- Batch 5/7 / Loss:  0.1343978
#    -- Batch 6/7 / Loss:  0.12427047
#    -- Batch 7/7 / Loss:  0.1260506
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13120438}
#    Validation: {'f1': 0.9725581407546997, 'loss': 0.13205163180828094}
#    Saving to: epoch_19_model.ckpt
# Epoch 20/100
#    -- Batch 1/7 / Loss:  0.13539807
#    -- Batch 2/7 / Loss:  0.13545936
#    -- Batch 3/7 / Loss:  0.11973774
#    -- Batch 4/7 / Loss:  0.12348682
#    -- Batch 5/7 / Loss:  0.13134769
#    -- Batch 6/7 / Loss:  0.12529568
#    -- Batch 7/7 / Loss:  0.12473517
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12792294}
#    Validation: {'f1': 0.9731967449188232, 'loss': 0.12955929338932037}
#    Saving to: epoch_20_model.ckpt
# Epoch 21/100
#    -- Batch 1/7 / Loss:  0.11961767
#    -- Batch 2/7 / Loss:  0.12707773
#    -- Batch 3/7 / Loss:  0.13461918
#    -- Batch 4/7 / Loss:  0.13202234
#    -- Batch 5/7 / Loss:  0.1295348
#    -- Batch 6/7 / Loss:  0.121409774
#    -- Batch 7/7 / Loss:  0.11700835
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12589854}
#    Validation: {'f1': 0.9732689261436462, 'loss': 0.12801282107830048}
#    Saving to: epoch_21_model.ckpt
# Epoch 22/100
#    -- Batch 1/7 / Loss:  0.12964882
#    -- Batch 2/7 / Loss:  0.124710605
#    -- Batch 3/7 / Loss:  0.12770084
#    -- Batch 4/7 / Loss:  0.12027956
#    -- Batch 5/7 / Loss:  0.12423613
#    -- Batch 6/7 / Loss:  0.11843608
#    -- Batch 7/7 / Loss:  0.12679864
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12454438}
#    Validation: {'f1': 0.9711589813232422, 'loss': 0.13038834929466248}
#    Saving to: epoch_22_model.ckpt
# Epoch 23/100
#    -- Batch 1/7 / Loss:  0.12885483
#    -- Batch 2/7 / Loss:  0.11712772
#    -- Batch 3/7 / Loss:  0.13111167
#    -- Batch 4/7 / Loss:  0.12287501
#    -- Batch 5/7 / Loss:  0.12644407
#    -- Batch 6/7 / Loss:  0.12077813
#    -- Batch 7/7 / Loss:  0.11509151
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12318327}
#    Validation: {'f1': 0.9734419584274292, 'loss': 0.1254366636276245}
#    Saving to: epoch_23_model.ckpt
# Epoch 24/100
#    -- Batch 1/7 / Loss:  0.11465438
#    -- Batch 2/7 / Loss:  0.11183881
#    -- Batch 3/7 / Loss:  0.11669298
#    -- Batch 4/7 / Loss:  0.13273184
#    -- Batch 5/7 / Loss:  0.12562901
#    -- Batch 6/7 / Loss:  0.115124114
#    -- Batch 7/7 / Loss:  0.12279906
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11992431}
#    Validation: {'f1': 0.9746533036231995, 'loss': 0.12295600771903992}
#    Saving to: epoch_24_model.ckpt
# Epoch 25/100
#    -- Batch 1/7 / Loss:  0.120794706
#    -- Batch 2/7 / Loss:  0.117040396
#    -- Batch 3/7 / Loss:  0.121062264
#    -- Batch 4/7 / Loss:  0.10875845
#    -- Batch 5/7 / Loss:  0.12394985
#    -- Batch 6/7 / Loss:  0.11110064
#    -- Batch 7/7 / Loss:  0.11663274
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.117048435}
#    Validation: {'f1': 0.9748592376708984, 'loss': 0.12154316157102585}
#    Saving to: epoch_25_model.ckpt
# Epoch 26/100
#    -- Batch 1/7 / Loss:  0.113873474
#    -- Batch 2/7 / Loss:  0.10533003
#    -- Batch 3/7 / Loss:  0.11529749
#    -- Batch 4/7 / Loss:  0.11644061
#    -- Batch 5/7 / Loss:  0.12870821
#    -- Batch 6/7 / Loss:  0.11916648
#    -- Batch 7/7 / Loss:  0.10984168
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11552257}
#    Validation: {'f1': 0.9752258062362671, 'loss': 0.11976742744445801}
#    Saving to: epoch_26_model.ckpt
# Epoch 27/100
#    -- Batch 1/7 / Loss:  0.11030259
#    -- Batch 2/7 / Loss:  0.11703234
#    -- Batch 3/7 / Loss:  0.12112008
#    -- Batch 4/7 / Loss:  0.11167898
#    -- Batch 5/7 / Loss:  0.10759944
#    -- Batch 6/7 / Loss:  0.11142509
#    -- Batch 7/7 / Loss:  0.11214465
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11304331}
#    Validation: {'f1': 0.9749913215637207, 'loss': 0.11665759235620499}
#    Saving to: epoch_27_model.ckpt
# Epoch 28/100
#    -- Batch 1/7 / Loss:  0.11528595
#    -- Batch 2/7 / Loss:  0.106726885
#    -- Batch 3/7 / Loss:  0.11554507
#    -- Batch 4/7 / Loss:  0.103157885
#    -- Batch 5/7 / Loss:  0.11642732
#    -- Batch 6/7 / Loss:  0.101177186
#    -- Batch 7/7 / Loss:  0.12110639
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11134667}
#    Validation: {'f1': 0.9749581813812256, 'loss': 0.1152799054980278}
#    Saving to: epoch_28_model.ckpt
# Epoch 29/100
#    -- Batch 1/7 / Loss:  0.102875486
#    -- Batch 2/7 / Loss:  0.101347044
#    -- Batch 3/7 / Loss:  0.11714497
#    -- Batch 4/7 / Loss:  0.112458244
#    -- Batch 5/7 / Loss:  0.11313129
#    -- Batch 6/7 / Loss:  0.11268
#    -- Batch 7/7 / Loss:  0.11060534
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11003463}
#    Validation: {'f1': 0.9755271673202515, 'loss': 0.11481923609972}
#    Saving to: epoch_29_model.ckpt
# Epoch 30/100
#    -- Batch 1/7 / Loss:  0.116661735
#    -- Batch 2/7 / Loss:  0.10444891
#    -- Batch 3/7 / Loss:  0.112434
#    -- Batch 4/7 / Loss:  0.10906516
#    -- Batch 5/7 / Loss:  0.1084433
#    -- Batch 6/7 / Loss:  0.09903042
#    -- Batch 7/7 / Loss:  0.108790964
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10841065}
#    Validation: {'f1': 0.9757912158966064, 'loss': 0.11297443509101868}
#    Saving to: epoch_30_model.ckpt
# Epoch 31/100
#    -- Batch 1/7 / Loss:  0.10795912
#    -- Batch 2/7 / Loss:  0.10401227
#    -- Batch 3/7 / Loss:  0.1044733
#    -- Batch 4/7 / Loss:  0.11108663
#    -- Batch 5/7 / Loss:  0.10426617
#    -- Batch 6/7 / Loss:  0.10802357
#    -- Batch 7/7 / Loss:  0.10864031
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10692306}
#    Validation: {'f1': 0.9749070405960083, 'loss': 0.11311876028776169}
#    Saving to: epoch_31_model.ckpt
# Epoch 32/100
#    -- Batch 1/7 / Loss:  0.10531015
#    -- Batch 2/7 / Loss:  0.099484295
#    -- Batch 3/7 / Loss:  0.10156666
#    -- Batch 4/7 / Loss:  0.10843788
#    -- Batch 5/7 / Loss:  0.10869349
#    -- Batch 6/7 / Loss:  0.09767187
#    -- Batch 7/7 / Loss:  0.11308902
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.104893334}
#    Validation: {'f1': 0.9764391183853149, 'loss': 0.11037807911634445}
#    Saving to: epoch_32_model.ckpt
# Epoch 33/100
#    -- Batch 1/7 / Loss:  0.10694712
#    -- Batch 2/7 / Loss:  0.10305367
#    -- Batch 3/7 / Loss:  0.09821015
#    -- Batch 4/7 / Loss:  0.11628819
#    -- Batch 5/7 / Loss:  0.10636237
#    -- Batch 6/7 / Loss:  0.098002285
#    -- Batch 7/7 / Loss:  0.09797159
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10383362}
#    Validation: {'f1': 0.9761465787887573, 'loss': 0.10883035510778427}
#    Saving to: epoch_33_model.ckpt
# Epoch 34/100
#    -- Batch 1/7 / Loss:  0.09837116
#    -- Batch 2/7 / Loss:  0.09590387
#    -- Batch 3/7 / Loss:  0.09813837
#    -- Batch 4/7 / Loss:  0.10458639
#    -- Batch 5/7 / Loss:  0.10990362
#    -- Batch 6/7 / Loss:  0.10421777
#    -- Batch 7/7 / Loss:  0.1053959
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.102359585}
#    Validation: {'f1': 0.9733984470367432, 'loss': 0.11307146400213242}
#    Saving to: epoch_34_model.ckpt
# Epoch 35/100
#    -- Batch 1/7 / Loss:  0.10587426
#    -- Batch 2/7 / Loss:  0.10000511
#    -- Batch 3/7 / Loss:  0.103697784
#    -- Batch 4/7 / Loss:  0.09863503
#    -- Batch 5/7 / Loss:  0.10565648
#    -- Batch 6/7 / Loss:  0.10842947
#    -- Batch 7/7 / Loss:  0.09093244
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10189009}
#    Validation: {'f1': 0.9760564565658569, 'loss': 0.10780271887779236}
#    Saving to: epoch_35_model.ckpt
# Epoch 36/100
#    -- Batch 1/7 / Loss:  0.09853053
#    -- Batch 2/7 / Loss:  0.10306066
#    -- Batch 3/7 / Loss:  0.091792434
#    -- Batch 4/7 / Loss:  0.11036497
#    -- Batch 5/7 / Loss:  0.10265131
#    -- Batch 6/7 / Loss:  0.09659615
#    -- Batch 7/7 / Loss:  0.09666795
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.099952005}
#    Validation: {'f1': 0.976154625415802, 'loss': 0.10581108927726746}
#    Saving to: epoch_36_model.ckpt
# Epoch 37/100
#    -- Batch 1/7 / Loss:  0.0917847
#    -- Batch 2/7 / Loss:  0.10173381
#    -- Batch 3/7 / Loss:  0.097452216
#    -- Batch 4/7 / Loss:  0.09809779
#    -- Batch 5/7 / Loss:  0.097786054
#    -- Batch 6/7 / Loss:  0.09273162
#    -- Batch 7/7 / Loss:  0.108883165
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09835277}
#    Validation: {'f1': 0.9765575528144836, 'loss': 0.10324501991271973}
#    Saving to: epoch_37_model.ckpt
# Epoch 38/100
#    -- Batch 1/7 / Loss:  0.08842291
#    -- Batch 2/7 / Loss:  0.09851751
#    -- Batch 3/7 / Loss:  0.095643714
#    -- Batch 4/7 / Loss:  0.103271425
#    -- Batch 5/7 / Loss:  0.105572075
#    -- Batch 6/7 / Loss:  0.089515105
#    -- Batch 7/7 / Loss:  0.09555744
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09664289}
#    Validation: {'f1': 0.9768646359443665, 'loss': 0.10295645147562027}
#    Saving to: epoch_38_model.ckpt
# Epoch 39/100
#    -- Batch 1/7 / Loss:  0.09671107
#    -- Batch 2/7 / Loss:  0.09892058
#    -- Batch 3/7 / Loss:  0.096281804
#    -- Batch 4/7 / Loss:  0.089104965
#    -- Batch 5/7 / Loss:  0.092050225
#    -- Batch 6/7 / Loss:  0.100570865
#    -- Batch 7/7 / Loss:  0.09072817
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09490967}
#    Validation: {'f1': 0.9769272804260254, 'loss': 0.10093129426240921}
#    Saving to: epoch_39_model.ckpt
# Epoch 40/100
#    -- Batch 1/7 / Loss:  0.09133495
#    -- Batch 2/7 / Loss:  0.09847926
#    -- Batch 3/7 / Loss:  0.09123337
#    -- Batch 4/7 / Loss:  0.08939828
#    -- Batch 5/7 / Loss:  0.09301797
#    -- Batch 6/7 / Loss:  0.093856454
#    -- Batch 7/7 / Loss:  0.0970988
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09348844}
#    Validation: {'f1': 0.9761179685592651, 'loss': 0.1011010929942131}
#    Saving to: epoch_40_model.ckpt
# Epoch 41/100
#    -- Batch 1/7 / Loss:  0.094317935
#    -- Batch 2/7 / Loss:  0.094771214
#    -- Batch 3/7 / Loss:  0.09952048
#    -- Batch 4/7 / Loss:  0.08907307
#    -- Batch 5/7 / Loss:  0.09372767
#    -- Batch 6/7 / Loss:  0.086522676
#    -- Batch 7/7 / Loss:  0.08778783
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09224583}
#    Validation: {'f1': 0.977522611618042, 'loss': 0.09753966331481934}
#    Saving to: epoch_41_model.ckpt
# Epoch 42/100
#    -- Batch 1/7 / Loss:  0.09540819
#    -- Batch 2/7 / Loss:  0.09243813
#    -- Batch 3/7 / Loss:  0.08161396
#    -- Batch 4/7 / Loss:  0.087944135
#    -- Batch 5/7 / Loss:  0.097947486
#    -- Batch 6/7 / Loss:  0.09420626
#    -- Batch 7/7 / Loss:  0.08773295
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09104159}
#    Validation: {'f1': 0.9771831631660461, 'loss': 0.09915253520011902}
#    Saving to: epoch_42_model.ckpt
# Epoch 43/100
#    -- Batch 1/7 / Loss:  0.08895192
#    -- Batch 2/7 / Loss:  0.09697986
#    -- Batch 3/7 / Loss:  0.085497424
#    -- Batch 4/7 / Loss:  0.09258004
#    -- Batch 5/7 / Loss:  0.08974393
#    -- Batch 6/7 / Loss:  0.08488777
#    -- Batch 7/7 / Loss:  0.09178394
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0900607}
#    Validation: {'f1': 0.9772406816482544, 'loss': 0.09742081165313721}
#    Saving to: epoch_43_model.ckpt
# Epoch 44/100
#    -- Batch 1/7 / Loss:  0.09333825
#    -- Batch 2/7 / Loss:  0.08876058
#    -- Batch 3/7 / Loss:  0.085848056
#    -- Batch 4/7 / Loss:  0.09103097
#    -- Batch 5/7 / Loss:  0.089023925
#    -- Batch 6/7 / Loss:  0.08695415
#    -- Batch 7/7 / Loss:  0.08229114
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08817815}
#    Validation: {'f1': 0.9777928590774536, 'loss': 0.09595512598752975}
#    Saving to: epoch_44_model.ckpt
# Epoch 45/100
#    -- Batch 1/7 / Loss:  0.0875009
#    -- Batch 2/7 / Loss:  0.08464521
#    -- Batch 3/7 / Loss:  0.0878147
#    -- Batch 4/7 / Loss:  0.08745742
#    -- Batch 5/7 / Loss:  0.08570707
#    -- Batch 6/7 / Loss:  0.094182625
#    -- Batch 7/7 / Loss:  0.0824447
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.087107524}
#    Validation: {'f1': 0.9775630831718445, 'loss': 0.09634178876876831}
#    Saving to: epoch_45_model.ckpt
# Epoch 46/100
#    -- Batch 1/7 / Loss:  0.08072045
#    -- Batch 2/7 / Loss:  0.086855374
#    -- Batch 3/7 / Loss:  0.081906974
#    -- Batch 4/7 / Loss:  0.08871202
#    -- Batch 5/7 / Loss:  0.088883564
#    -- Batch 6/7 / Loss:  0.081283025
#    -- Batch 7/7 / Loss:  0.09556414
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08627508}
#    Validation: {'f1': 0.9774691462516785, 'loss': 0.09517612308263779}
#    Saving to: epoch_46_model.ckpt
# Epoch 47/100
#    -- Batch 1/7 / Loss:  0.08117936
#    -- Batch 2/7 / Loss:  0.09570495
#    -- Batch 3/7 / Loss:  0.08518529
#    -- Batch 4/7 / Loss:  0.08095924
#    -- Batch 5/7 / Loss:  0.08297844
#    -- Batch 6/7 / Loss:  0.08278913
#    -- Batch 7/7 / Loss:  0.09292891
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08596075}
#    Validation: {'f1': 0.9778842329978943, 'loss': 0.09324228763580322}
#    Saving to: epoch_47_model.ckpt
# Epoch 48/100
#    -- Batch 1/7 / Loss:  0.07823986
#    -- Batch 2/7 / Loss:  0.082026035
#    -- Batch 3/7 / Loss:  0.08263141
#    -- Batch 4/7 / Loss:  0.09022574
#    -- Batch 5/7 / Loss:  0.08588819
#    -- Batch 6/7 / Loss:  0.09174519
#    -- Batch 7/7 / Loss:  0.082038626
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08468501}
#    Validation: {'f1': 0.9772540330886841, 'loss': 0.09513076394796371}
#    Saving to: epoch_48_model.ckpt
# Epoch 49/100
#    -- Batch 1/7 / Loss:  0.085279524
#    -- Batch 2/7 / Loss:  0.08249914
#    -- Batch 3/7 / Loss:  0.07737877
#    -- Batch 4/7 / Loss:  0.08240803
#    -- Batch 5/7 / Loss:  0.08978026
#    -- Batch 6/7 / Loss:  0.08512481
#    -- Batch 7/7 / Loss:  0.07963089
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08315735}
#    Validation: {'f1': 0.9768621921539307, 'loss': 0.09501868486404419}
#    Saving to: epoch_49_model.ckpt
# Epoch 50/100
#    -- Batch 1/7 / Loss:  0.08011603
#    -- Batch 2/7 / Loss:  0.08252647
#    -- Batch 3/7 / Loss:  0.08498661
#    -- Batch 4/7 / Loss:  0.078782745
#    -- Batch 5/7 / Loss:  0.08855782
#    -- Batch 6/7 / Loss:  0.08226263
#    -- Batch 7/7 / Loss:  0.080924
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.082593754}
#    Validation: {'f1': 0.978352427482605, 'loss': 0.09052035957574844}
#    Saving to: epoch_50_model.ckpt
# Epoch 51/100
#    -- Batch 1/7 / Loss:  0.07594327
#    -- Batch 2/7 / Loss:  0.089499064
#    -- Batch 3/7 / Loss:  0.07638146
#    -- Batch 4/7 / Loss:  0.08616121
#    -- Batch 5/7 / Loss:  0.0858276
#    -- Batch 6/7 / Loss:  0.081793845
#    -- Batch 7/7 / Loss:  0.07821536
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08197454}
#    Validation: {'f1': 0.9772204756736755, 'loss': 0.09238437563180923}
#    Saving to: epoch_51_model.ckpt
# Epoch 52/100
#    -- Batch 1/7 / Loss:  0.08252429
#    -- Batch 2/7 / Loss:  0.08105491
#    -- Batch 3/7 / Loss:  0.07845736
#    -- Batch 4/7 / Loss:  0.076456465
#    -- Batch 5/7 / Loss:  0.078575574
#    -- Batch 6/7 / Loss:  0.08101317
#    -- Batch 7/7 / Loss:  0.083259024
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.080191545}
#    Validation: {'f1': 0.977641761302948, 'loss': 0.09040654450654984}
#    Saving to: epoch_52_model.ckpt
# Epoch 53/100
#    -- Batch 1/7 / Loss:  0.080217674
#    -- Batch 2/7 / Loss:  0.080142066
#    -- Batch 3/7 / Loss:  0.076899216
#    -- Batch 4/7 / Loss:  0.082602136
#    -- Batch 5/7 / Loss:  0.07385282
#    -- Batch 6/7 / Loss:  0.08137639
#    -- Batch 7/7 / Loss:  0.08262737
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.079673946}
#    Validation: {'f1': 0.9782553911209106, 'loss': 0.08823569864034653}
#    Saving to: epoch_53_model.ckpt
# Epoch 54/100
#    -- Batch 1/7 / Loss:  0.08014016
#    -- Batch 2/7 / Loss:  0.082634725
#    -- Batch 3/7 / Loss:  0.07949698
#    -- Batch 4/7 / Loss:  0.07558207
#    -- Batch 5/7 / Loss:  0.07695899
#    -- Batch 6/7 / Loss:  0.07403174
#    -- Batch 7/7 / Loss:  0.08299074
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07883363}
#    Validation: {'f1': 0.9778265953063965, 'loss': 0.08796697854995728}
#    Saving to: epoch_54_model.ckpt
# Epoch 55/100
#    -- Batch 1/7 / Loss:  0.08021371
#    -- Batch 2/7 / Loss:  0.08399873
#    -- Batch 3/7 / Loss:  0.0781263
#    -- Batch 4/7 / Loss:  0.07744925
#    -- Batch 5/7 / Loss:  0.07886108
#    -- Batch 6/7 / Loss:  0.0780075
#    -- Batch 7/7 / Loss:  0.07221335
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.078409985}
#    Validation: {'f1': 0.977035641670227, 'loss': 0.08809681981801987}
#    Saving to: epoch_55_model.ckpt
# Epoch 56/100
#    -- Batch 1/7 / Loss:  0.07977664
#    -- Batch 2/7 / Loss:  0.086399175
#    -- Batch 3/7 / Loss:  0.075055905
#    -- Batch 4/7 / Loss:  0.0782152
#    -- Batch 5/7 / Loss:  0.08027338
#    -- Batch 6/7 / Loss:  0.07441634
#    -- Batch 7/7 / Loss:  0.07547754
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07851631}
#    Validation: {'f1': 0.9782311320304871, 'loss': 0.08566614240407944}
#    Saving to: epoch_56_model.ckpt
# Epoch 57/100
#    -- Batch 1/7 / Loss:  0.077647224
#    -- Batch 2/7 / Loss:  0.0845194
#    -- Batch 3/7 / Loss:  0.07174704
#    -- Batch 4/7 / Loss:  0.08613401
#    -- Batch 5/7 / Loss:  0.070992276
#    -- Batch 6/7 / Loss:  0.07873972
#    -- Batch 7/7 / Loss:  0.0775031
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07818325}
#    Validation: {'f1': 0.9777056574821472, 'loss': 0.08787452429533005}
#    Saving to: epoch_57_model.ckpt
# Epoch 58/100
#    -- Batch 1/7 / Loss:  0.07333736
#    -- Batch 2/7 / Loss:  0.074672036
#    -- Batch 3/7 / Loss:  0.072245955
#    -- Batch 4/7 / Loss:  0.08039822
#    -- Batch 5/7 / Loss:  0.08492525
#    -- Batch 6/7 / Loss:  0.08167087
#    -- Batch 7/7 / Loss:  0.07298201
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07717596}
#    Validation: {'f1': 0.9769350290298462, 'loss': 0.08949360996484756}
#    Saving to: epoch_58_model.ckpt
# Epoch 59/100
#    -- Batch 1/7 / Loss:  0.07372084
#    -- Batch 2/7 / Loss:  0.071902424
#    -- Batch 3/7 / Loss:  0.075136214
#    -- Batch 4/7 / Loss:  0.07603619
#    -- Batch 5/7 / Loss:  0.08112589
#    -- Batch 6/7 / Loss:  0.07886825
#    -- Batch 7/7 / Loss:  0.075915344
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07610073}
#    Validation: {'f1': 0.9761813879013062, 'loss': 0.09017036110162735}
#    Saving to: epoch_59_model.ckpt
# Epoch 60/100
#    -- Batch 1/7 / Loss:  0.0768341
#    -- Batch 2/7 / Loss:  0.08116079
#    -- Batch 3/7 / Loss:  0.071573846
#    -- Batch 4/7 / Loss:  0.07169169
#    -- Batch 5/7 / Loss:  0.07327127
#    -- Batch 6/7 / Loss:  0.067548156
#    -- Batch 7/7 / Loss:  0.078727536
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07440106}
#    Validation: {'f1': 0.9782422184944153, 'loss': 0.08369850367307663}
#    Saving to: epoch_60_model.ckpt
# Epoch 61/100
#    -- Batch 1/7 / Loss:  0.07310241
#    -- Batch 2/7 / Loss:  0.07265159
#    -- Batch 3/7 / Loss:  0.075454935
#    -- Batch 4/7 / Loss:  0.07116303
#    -- Batch 5/7 / Loss:  0.07118702
#    -- Batch 6/7 / Loss:  0.07749582
#    -- Batch 7/7 / Loss:  0.06980509
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07297999}
#    Validation: {'f1': 0.9777126908302307, 'loss': 0.08411609381437302}
#    Saving to: epoch_61_model.ckpt
# Epoch 62/100
#    -- Batch 1/7 / Loss:  0.07692579
#    -- Batch 2/7 / Loss:  0.07367787
#    -- Batch 3/7 / Loss:  0.06405548
#    -- Batch 4/7 / Loss:  0.07382823
#    -- Batch 5/7 / Loss:  0.07341281
#    -- Batch 6/7 / Loss:  0.07650729
#    -- Batch 7/7 / Loss:  0.06858388
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07242733}
#    Validation: {'f1': 0.9778246879577637, 'loss': 0.08463216572999954}
#    Saving to: epoch_62_model.ckpt
# Epoch 63/100
#    -- Batch 1/7 / Loss:  0.07426703
#    -- Batch 2/7 / Loss:  0.0728878
#    -- Batch 3/7 / Loss:  0.069526024
#    -- Batch 4/7 / Loss:  0.06905354
#    -- Batch 5/7 / Loss:  0.065200455
#    -- Batch 6/7 / Loss:  0.07836688
#    -- Batch 7/7 / Loss:  0.069156244
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07120828}
#    Validation: {'f1': 0.9780480265617371, 'loss': 0.08214155584573746}
#    Saving to: epoch_63_model.ckpt
# Epoch 64/100
#    -- Batch 1/7 / Loss:  0.068977386
#    -- Batch 2/7 / Loss:  0.07600369
#    -- Batch 3/7 / Loss:  0.06827187
#    -- Batch 4/7 / Loss:  0.07187847
#    -- Batch 5/7 / Loss:  0.0696713
#    -- Batch 6/7 / Loss:  0.07114718
#    -- Batch 7/7 / Loss:  0.064849354
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07011418}
#    Validation: {'f1': 0.9786971807479858, 'loss': 0.08097858726978302}
#    Saving to: epoch_64_model.ckpt
# Epoch 65/100
#    -- Batch 1/7 / Loss:  0.07717902
#    -- Batch 2/7 / Loss:  0.07161046
#    -- Batch 3/7 / Loss:  0.06558232
#    -- Batch 4/7 / Loss:  0.06547798
#    -- Batch 5/7 / Loss:  0.06575312
#    -- Batch 6/7 / Loss:  0.07878996
#    -- Batch 7/7 / Loss:  0.06695881
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07019309}
#    Validation: {'f1': 0.9778733253479004, 'loss': 0.08250052481889725}
#    Saving to: epoch_65_model.ckpt
# Epoch 66/100
#    -- Batch 1/7 / Loss:  0.07141932
#    -- Batch 2/7 / Loss:  0.07431392
#    -- Batch 3/7 / Loss:  0.06521942
#    -- Batch 4/7 / Loss:  0.066522405
#    -- Batch 5/7 / Loss:  0.06763359
#    -- Batch 6/7 / Loss:  0.06769284
#    -- Batch 7/7 / Loss:  0.07019531
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.068999544}
#    Validation: {'f1': 0.9772588014602661, 'loss': 0.0822935402393341}
#    Saving to: epoch_66_model.ckpt
# Epoch 67/100
#    -- Batch 1/7 / Loss:  0.06668711
#    -- Batch 2/7 / Loss:  0.069312975
#    -- Batch 3/7 / Loss:  0.06854519
#    -- Batch 4/7 / Loss:  0.0709978
#    -- Batch 5/7 / Loss:  0.06891039
#    -- Batch 6/7 / Loss:  0.0657491
#    -- Batch 7/7 / Loss:  0.0672489
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06820735}
#    Validation: {'f1': 0.9774678945541382, 'loss': 0.08270871639251709}
#    Saving to: epoch_67_model.ckpt
# Epoch 68/100
#    -- Batch 1/7 / Loss:  0.06743085
#    -- Batch 2/7 / Loss:  0.07328571
#    -- Batch 3/7 / Loss:  0.06667651
#    -- Batch 4/7 / Loss:  0.065197624
#    -- Batch 5/7 / Loss:  0.07417005
#    -- Batch 6/7 / Loss:  0.06859622
#    -- Batch 7/7 / Loss:  0.064247206
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06851488}
#    Validation: {'f1': 0.9769299030303955, 'loss': 0.08356782048940659}
#    Saving to: epoch_68_model.ckpt
# Epoch 69/100
#    -- Batch 1/7 / Loss:  0.06567503
#    -- Batch 2/7 / Loss:  0.06781495
#    -- Batch 3/7 / Loss:  0.06460254
#    -- Batch 4/7 / Loss:  0.061523817
#    -- Batch 5/7 / Loss:  0.07053682
#    -- Batch 6/7 / Loss:  0.0710796
#    -- Batch 7/7 / Loss:  0.06755539
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06696974}
#    Validation: {'f1': 0.9781703948974609, 'loss': 0.08043266087770462}
#    Saving to: epoch_69_model.ckpt
# Epoch 70/100
#    -- Batch 1/7 / Loss:  0.06185939
#    -- Batch 2/7 / Loss:  0.073829375
#    -- Batch 3/7 / Loss:  0.06782556
#    -- Batch 4/7 / Loss:  0.06510114
#    -- Batch 5/7 / Loss:  0.06451849
#    -- Batch 6/7 / Loss:  0.064610206
#    -- Batch 7/7 / Loss:  0.06673901
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.066354744}
#    Validation: {'f1': 0.9786182641983032, 'loss': 0.07811395078897476}
#    Saving to: epoch_70_model.ckpt
# Epoch 71/100
#    -- Batch 1/7 / Loss:  0.06323144
#    -- Batch 2/7 / Loss:  0.06046006
#    -- Batch 3/7 / Loss:  0.06676689
#    -- Batch 4/7 / Loss:  0.066417195
#    -- Batch 5/7 / Loss:  0.06738128
#    -- Batch 6/7 / Loss:  0.07098756
#    -- Batch 7/7 / Loss:  0.06634701
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.065941624}
#    Validation: {'f1': 0.9774457812309265, 'loss': 0.08085449039936066}
#    Saving to: epoch_71_model.ckpt
# Epoch 72/100
#    -- Batch 1/7 / Loss:  0.06640119
#    -- Batch 2/7 / Loss:  0.06351452
#    -- Batch 3/7 / Loss:  0.06633216
#    -- Batch 4/7 / Loss:  0.06036552
#    -- Batch 5/7 / Loss:  0.06063754
#    -- Batch 6/7 / Loss:  0.06430117
#    -- Batch 7/7 / Loss:  0.07147448
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06471808}
#    Validation: {'f1': 0.9777836799621582, 'loss': 0.0791589766740799}
#    Saving to: epoch_72_model.ckpt
# Epoch 73/100
#    -- Batch 1/7 / Loss:  0.059572592
#    -- Batch 2/7 / Loss:  0.06399405
#    -- Batch 3/7 / Loss:  0.064110085
#    -- Batch 4/7 / Loss:  0.06620653
#    -- Batch 5/7 / Loss:  0.06090758
#    -- Batch 6/7 / Loss:  0.07347337
#    -- Batch 7/7 / Loss:  0.06042449
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06409838}
#    Validation: {'f1': 0.9786837100982666, 'loss': 0.07705015689134598}
#    Saving to: epoch_73_model.ckpt
# Epoch 74/100
#    -- Batch 1/7 / Loss:  0.063899785
#    -- Batch 2/7 / Loss:  0.06634954
#    -- Batch 3/7 / Loss:  0.059574626
#    -- Batch 4/7 / Loss:  0.060397543
#    -- Batch 5/7 / Loss:  0.060950253
#    -- Batch 6/7 / Loss:  0.07202549
#    -- Batch 7/7 / Loss:  0.062385045
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06365462}
#    Validation: {'f1': 0.9786288738250732, 'loss': 0.07722317427396774}
#    Saving to: epoch_74_model.ckpt
# Epoch 75/100
#    -- Batch 1/7 / Loss:  0.07175915
#    -- Batch 2/7 / Loss:  0.06387349
#    -- Batch 3/7 / Loss:  0.06519531
#    -- Batch 4/7 / Loss:  0.060827058
#    -- Batch 5/7 / Loss:  0.05956474
#    -- Batch 6/7 / Loss:  0.059524648
#    -- Batch 7/7 / Loss:  0.06425717
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.063571654}
#    Validation: {'f1': 0.978169322013855, 'loss': 0.07639940828084946}
#    Saving to: epoch_75_model.ckpt
# Epoch 76/100
#    -- Batch 1/7 / Loss:  0.07919031
#    -- Batch 2/7 / Loss:  0.061976127
#    -- Batch 3/7 / Loss:  0.06162633
#    -- Batch 4/7 / Loss:  0.062104616
#    -- Batch 5/7 / Loss:  0.061108317
#    -- Batch 6/7 / Loss:  0.061452385
#    -- Batch 7/7 / Loss:  0.058546737
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06371497}
#    Validation: {'f1': 0.9785095453262329, 'loss': 0.07622861117124557}
#    Saving to: epoch_76_model.ckpt
# Epoch 77/100
#    -- Batch 1/7 / Loss:  0.06637114
#    -- Batch 2/7 / Loss:  0.07503651
#    -- Batch 3/7 / Loss:  0.058894783
#    -- Batch 4/7 / Loss:  0.06083195
#    -- Batch 5/7 / Loss:  0.058401182
#    -- Batch 6/7 / Loss:  0.05823731
#    -- Batch 7/7 / Loss:  0.056229252
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.062000304}
#    Validation: {'f1': 0.9788709878921509, 'loss': 0.0747121050953865}
#    Saving to: epoch_77_model.ckpt
# Epoch 78/100
#    -- Batch 1/7 / Loss:  0.05738421
#    -- Batch 2/7 / Loss:  0.059940338
#    -- Batch 3/7 / Loss:  0.06606201
#    -- Batch 4/7 / Loss:  0.05456636
#    -- Batch 5/7 / Loss:  0.061074242
#    -- Batch 6/7 / Loss:  0.06683921
#    -- Batch 7/7 / Loss:  0.06173397
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06108576}
#    Validation: {'f1': 0.9784342050552368, 'loss': 0.07625716179609299}
#    Saving to: epoch_78_model.ckpt
# Epoch 79/100
#    -- Batch 1/7 / Loss:  0.059712205
#    -- Batch 2/7 / Loss:  0.057566665
#    -- Batch 3/7 / Loss:  0.06388213
#    -- Batch 4/7 / Loss:  0.061584458
#    -- Batch 5/7 / Loss:  0.05560185
#    -- Batch 6/7 / Loss:  0.06840918
#    -- Batch 7/7 / Loss:  0.060927123
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.061097655}
#    Validation: {'f1': 0.9782143831253052, 'loss': 0.07519840449094772}
#    Saving to: epoch_79_model.ckpt
# Epoch 80/100
#    -- Batch 1/7 / Loss:  0.058453653
#    -- Batch 2/7 / Loss:  0.06528088
#    -- Batch 3/7 / Loss:  0.058941655
#    -- Batch 4/7 / Loss:  0.06250324
#    -- Batch 5/7 / Loss:  0.059354063
#    -- Batch 6/7 / Loss:  0.055029355
#    -- Batch 7/7 / Loss:  0.06613975
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06081466}
#    Validation: {'f1': 0.9786378145217896, 'loss': 0.07392825931310654}
#    Saving to: epoch_80_model.ckpt
# Epoch 81/100
#    -- Batch 1/7 / Loss:  0.06119567
#    -- Batch 2/7 / Loss:  0.058561523
#    -- Batch 3/7 / Loss:  0.057897016
#    -- Batch 4/7 / Loss:  0.05982141
#    -- Batch 5/7 / Loss:  0.0618192
#    -- Batch 6/7 / Loss:  0.056726087
#    -- Batch 7/7 / Loss:  0.0622991
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.059760004}
#    Validation: {'f1': 0.9786807298660278, 'loss': 0.0741492435336113}
#    Saving to: epoch_81_model.ckpt
# Epoch 82/100
#    -- Batch 1/7 / Loss:  0.054113183
#    -- Batch 2/7 / Loss:  0.06211067
#    -- Batch 3/7 / Loss:  0.06649184
#    -- Batch 4/7 / Loss:  0.061034203
#    -- Batch 5/7 / Loss:  0.05950596
#    -- Batch 6/7 / Loss:  0.05804193
#    -- Batch 7/7 / Loss:  0.057779126
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05986813}
#    Validation: {'f1': 0.9781919717788696, 'loss': 0.0753328949213028}
#    Saving to: epoch_82_model.ckpt
# Epoch 83/100
#    -- Batch 1/7 / Loss:  0.06308545
#    -- Batch 2/7 / Loss:  0.051688425
#    -- Batch 3/7 / Loss:  0.06072018
#    -- Batch 4/7 / Loss:  0.056301493
#    -- Batch 5/7 / Loss:  0.05561239
#    -- Batch 6/7 / Loss:  0.067026064
#    -- Batch 7/7 / Loss:  0.061509658
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.059420526}
#    Validation: {'f1': 0.9780173301696777, 'loss': 0.07408855110406876}
#    Saving to: epoch_83_model.ckpt
# Epoch 84/100
#    -- Batch 1/7 / Loss:  0.062022895
#    -- Batch 2/7 / Loss:  0.05522433
#    -- Batch 3/7 / Loss:  0.05696755
#    -- Batch 4/7 / Loss:  0.05931853
#    -- Batch 5/7 / Loss:  0.056879807
#    -- Batch 6/7 / Loss:  0.058777887
#    -- Batch 7/7 / Loss:  0.06448045
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.059095923}
#    Validation: {'f1': 0.9792112112045288, 'loss': 0.07163569331169128}
#    Saving to: epoch_84_model.ckpt
# Epoch 85/100
#    -- Batch 1/7 / Loss:  0.059168883
#    -- Batch 2/7 / Loss:  0.055905946
#    -- Batch 3/7 / Loss:  0.060113885
#    -- Batch 4/7 / Loss:  0.057839375
#    -- Batch 5/7 / Loss:  0.05525919
#    -- Batch 6/7 / Loss:  0.054832675
#    -- Batch 7/7 / Loss:  0.05699336
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.057159044}
#    Validation: {'f1': 0.9787815809249878, 'loss': 0.07230915874242783}
#    Saving to: epoch_85_model.ckpt
# Epoch 86/100
#    -- Batch 1/7 / Loss:  0.054670442
#    -- Batch 2/7 / Loss:  0.051671736
#    -- Batch 3/7 / Loss:  0.058936957
#    -- Batch 4/7 / Loss:  0.058345918
#    -- Batch 5/7 / Loss:  0.054620735
#    -- Batch 6/7 / Loss:  0.056433335
#    -- Batch 7/7 / Loss:  0.058052767
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05610456}
#    Validation: {'f1': 0.9783236980438232, 'loss': 0.07336105406284332}
#    Saving to: epoch_86_model.ckpt
# Epoch 87/100
#    -- Batch 1/7 / Loss:  0.056776002
#    -- Batch 2/7 / Loss:  0.056310296
#    -- Batch 3/7 / Loss:  0.054033894
#    -- Batch 4/7 / Loss:  0.056887824
#    -- Batch 5/7 / Loss:  0.050392102
#    -- Batch 6/7 / Loss:  0.055651873
#    -- Batch 7/7 / Loss:  0.056234438
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.055183776}
#    Validation: {'f1': 0.9786981344223022, 'loss': 0.07205340266227722}
#    Saving to: epoch_87_model.ckpt
# Epoch 88/100
#    -- Batch 1/7 / Loss:  0.052799042
#    -- Batch 2/7 / Loss:  0.05687599
#    -- Batch 3/7 / Loss:  0.051021338
#    -- Batch 4/7 / Loss:  0.055228494
#    -- Batch 5/7 / Loss:  0.057285592
#    -- Batch 6/7 / Loss:  0.05409415
#    -- Batch 7/7 / Loss:  0.054979607
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.054612033}
#    Validation: {'f1': 0.9786593914031982, 'loss': 0.07264140993356705}
#    Saving to: epoch_88_model.ckpt
# Epoch 89/100
#    -- Batch 1/7 / Loss:  0.053159755
#    -- Batch 2/7 / Loss:  0.05462466
#    -- Batch 3/7 / Loss:  0.05168429
#    -- Batch 4/7 / Loss:  0.054509908
#    -- Batch 5/7 / Loss:  0.057706557
#    -- Batch 6/7 / Loss:  0.05412636
#    -- Batch 7/7 / Loss:  0.05231929
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.054018687}
#    Validation: {'f1': 0.9786763191223145, 'loss': 0.07165501266717911}
#    Saving to: epoch_89_model.ckpt
# Epoch 90/100
#    -- Batch 1/7 / Loss:  0.05407135
#    -- Batch 2/7 / Loss:  0.055206273
#    -- Batch 3/7 / Loss:  0.0536655
#    -- Batch 4/7 / Loss:  0.053234164
#    -- Batch 5/7 / Loss:  0.05580965
#    -- Batch 6/7 / Loss:  0.053701375
#    -- Batch 7/7 / Loss:  0.049725357
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.053630523}
#    Validation: {'f1': 0.978479266166687, 'loss': 0.07151149213314056}
#    Saving to: epoch_90_model.ckpt
# Epoch 91/100
#    -- Batch 1/7 / Loss:  0.05444114
#    -- Batch 2/7 / Loss:  0.05457992
#    -- Batch 3/7 / Loss:  0.059122812
#    -- Batch 4/7 / Loss:  0.050465595
#    -- Batch 5/7 / Loss:  0.051234365
#    -- Batch 6/7 / Loss:  0.051594943
#    -- Batch 7/7 / Loss:  0.0536478
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.053583793}
#    Validation: {'f1': 0.9786571264266968, 'loss': 0.07094784826040268}
#    Saving to: epoch_91_model.ckpt
# Epoch 92/100
#    -- Batch 1/7 / Loss:  0.052337132
#    -- Batch 2/7 / Loss:  0.05213056
#    -- Batch 3/7 / Loss:  0.050542332
#    -- Batch 4/7 / Loss:  0.049133867
#    -- Batch 5/7 / Loss:  0.05524172
#    -- Batch 6/7 / Loss:  0.051351726
#    -- Batch 7/7 / Loss:  0.054742638
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.052211422}
#    Validation: {'f1': 0.9787857532501221, 'loss': 0.07059457153081894}
#    Saving to: epoch_92_model.ckpt
# Epoch 93/100
#    -- Batch 1/7 / Loss:  0.050520122
#    -- Batch 2/7 / Loss:  0.050873764
#    -- Batch 3/7 / Loss:  0.05333162
#    -- Batch 4/7 / Loss:  0.049545046
#    -- Batch 5/7 / Loss:  0.05435215
#    -- Batch 6/7 / Loss:  0.05915234
#    -- Batch 7/7 / Loss:  0.048527323
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05232891}
#    Validation: {'f1': 0.9785627126693726, 'loss': 0.07080914825201035}
#    Saving to: epoch_93_model.ckpt
# Epoch 94/100
#    -- Batch 1/7 / Loss:  0.049934786
#    -- Batch 2/7 / Loss:  0.05030795
#    -- Batch 3/7 / Loss:  0.048735518
#    -- Batch 4/7 / Loss:  0.05430436
#    -- Batch 5/7 / Loss:  0.055953406
#    -- Batch 6/7 / Loss:  0.05084692
#    -- Batch 7/7 / Loss:  0.051949877
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.051718973}
#    Validation: {'f1': 0.9788047671318054, 'loss': 0.06993146240711212}
#    Saving to: epoch_94_model.ckpt
# Epoch 95/100
#    -- Batch 1/7 / Loss:  0.0503381
#    -- Batch 2/7 / Loss:  0.050034814
#    -- Batch 3/7 / Loss:  0.05043704
#    -- Batch 4/7 / Loss:  0.056257274
#    -- Batch 5/7 / Loss:  0.053320825
#    -- Batch 6/7 / Loss:  0.04835082
#    -- Batch 7/7 / Loss:  0.048283055
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.051003132}
#    Validation: {'f1': 0.9791519641876221, 'loss': 0.06889095157384872}
#    Saving to: epoch_95_model.ckpt
# Epoch 96/100
#    -- Batch 1/7 / Loss:  0.048216447
#    -- Batch 2/7 / Loss:  0.052043986
#    -- Batch 3/7 / Loss:  0.049828626
#    -- Batch 4/7 / Loss:  0.050670143
#    -- Batch 5/7 / Loss:  0.049218435
#    -- Batch 6/7 / Loss:  0.056077633
#    -- Batch 7/7 / Loss:  0.04991447
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.050852824}
#    Validation: {'f1': 0.9787932634353638, 'loss': 0.06947851181030273}
#    Saving to: epoch_96_model.ckpt
# Epoch 97/100
#    -- Batch 1/7 / Loss:  0.04944481
#    -- Batch 2/7 / Loss:  0.04768679
#    -- Batch 3/7 / Loss:  0.054267865
#    -- Batch 4/7 / Loss:  0.049322054
#    -- Batch 5/7 / Loss:  0.052097205
#    -- Batch 6/7 / Loss:  0.05068056
#    -- Batch 7/7 / Loss:  0.048588175
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05029821}
#    Validation: {'f1': 0.9786720275878906, 'loss': 0.06928323954343796}
#    Saving to: epoch_97_model.ckpt
# Epoch 98/100
#    -- Batch 1/7 / Loss:  0.049251527
#    -- Batch 2/7 / Loss:  0.04618077
#    -- Batch 3/7 / Loss:  0.055451035
#    -- Batch 4/7 / Loss:  0.053865638
#    -- Batch 5/7 / Loss:  0.049785186
#    -- Batch 6/7 / Loss:  0.05000735
#    -- Batch 7/7 / Loss:  0.051300544
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.050834578}
#    Validation: {'f1': 0.9789042472839355, 'loss': 0.06818325072526932}
#    Saving to: epoch_98_model.ckpt
# Epoch 99/100
#    -- Batch 1/7 / Loss:  0.054410256
#    -- Batch 2/7 / Loss:  0.04716189
#    -- Batch 3/7 / Loss:  0.0506742
#    -- Batch 4/7 / Loss:  0.05586625
#    -- Batch 5/7 / Loss:  0.051557317
#    -- Batch 6/7 / Loss:  0.049748383
#    -- Batch 7/7 / Loss:  0.050502256
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.051417224}
#    Validation: {'f1': 0.9788833856582642, 'loss': 0.06876570731401443}
#    Saving to: epoch_99_model.ckpt
# Epoch 100/100
#    -- Batch 1/7 / Loss:  0.052966118
#    -- Batch 2/7 / Loss:  0.049150992
#    -- Batch 3/7 / Loss:  0.051105842
#    -- Batch 4/7 / Loss:  0.051139235
#    -- Batch 5/7 / Loss:  0.053163197
#    -- Batch 6/7 / Loss:  0.049087822
#    -- Batch 7/7 / Loss:  0.048371397
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.050712086}
#    Validation: {'f1': 0.9787059426307678, 'loss': 0.06829140335321426}
#    Saving to: epoch_100_model.ckpt

# %% [markdown]
# ## Plot training and validation histories

# %%
plot_histories(train_history['loss'], val_history['loss'], label="Loss")
plot_histories(train_history=None, val_history=val_history['f1'], label="F1 Score")
plt.show()

# %% [markdown]
# ## Evaluate on single test-set image

# %%
# Predict on a test image
x_test, y_test = test_dataset[0]
if gpu:
  x_test = x_test.to(device)
  y_test = y_test.to(device)
pred = model(x_test.view(1, 1, x_test.shape[1], x_test.shape[2])).argmax(1).cpu().numpy()

# Plot the result
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 15))
ax1.set_title("True mask")
ax2.set_title("Predicted mask")

plot_image_with_segmentation(x_test.cpu(), y_test.cpu(), ax=ax1)
plot_image_with_segmentation(x_test.cpu(), pred, ax=ax2)

plt.show()

# %% [markdown]
# ## Evaluate on whole test-set

# %%
# OBS: Returns batch-wise metrics, but test_loader has batch_size = 1
f1_test_scores = evaluate_model(model, test_loader, metrics, reduction=False)["f1"]

print("Test cases:", len(f1_test_scores))
print("Mean F1:   ", np.mean(f1_test_scores))
print("STD  F1:   ", np.std(f1_test_scores))
print("Min. F1:   ", np.min(f1_test_scores))
# Out:
# Test cases: 123
# Mean F1:    0.9794246404151606
# STD  F1:    0.010202805467318958
# Min. F1:    0.9305341243743896
